# %%
import pandas as pd
from pathlib import Path
withdrawal_students = pd.read_csv("data/final_vle.csv")
withdrawal_students = withdrawal_students[withdrawal_students["final_result"] == "Withdrawn"]
withdrawal_students
# Out:
#        index code_module code_presentation  id_student gender  \
# 2          2         AAA             2013J       30268      F
# 15        15         AAA             2013J       65002      F
# 22        22         AAA             2013J       94961      M
# 29        29         AAA             2013J      106247      M
# 41        41         AAA             2013J      129955      M
# ...      ...         ...               ...         ...    ...
# 32576  32576         GGG             2014J     2338614      F
# 32577  32577         GGG             2014J     2342238      M
# 32578  32578         GGG             2014J     2357806      F
# 32586  32586         GGG             2014J     2608143      M
# 32591  32591         GGG             2014J     2679821      F
#
#                      region      highest_education imd_band age_band  \
# 2      North Western Region  A Level or Equivalent   30-40%    35-55
# 15      East Anglian Region  A Level or Equivalent   70-80%     0-35
# ...

# %%
withdrawal_students.dropna()
# Out:
#        index code_module code_presentation  id_student gender  \
# 15        15         AAA             2013J       65002      F
# 22        22         AAA             2013J       94961      M
# 29        29         AAA             2013J      106247      M
# 41        41         AAA             2013J      129955      M
# 45        45         AAA             2013J      135400      F
# ...      ...         ...               ...         ...    ...
# 32568  32568         GGG             2014J     2203216      F
# 32569  32569         GGG             2014J     2214722      F
# 32577  32577         GGG             2014J     2342238      M
# 32578  32578         GGG             2014J     2357806      F
# 32591  32591         GGG             2014J     2679821      F
#
#                      region      highest_education imd_band age_band  \
# 15      East Anglian Region  A Level or Equivalent   70-80%     0-35
# 22             South Region     Lower Than A Level   70-80%    35-55
# ...
