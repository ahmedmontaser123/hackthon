# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\XBOX2\Desktop\hackthons\hackthon\data\archive(1)\studentInfo.csv")

# %%
student_info = pd.DataFrame(data)

# %%
student_info.head()
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# 1               60          N         Pass
# ...

# %%
student_info['region'].unique()
# Out:
# array(['East Anglian Region', 'Scotland', 'North Western Region',
#        'South East Region', 'West Midlands Region', 'Wales',
#        'North Region', 'South Region', 'Ireland', 'South West Region',
#        'East Midlands Region', 'Yorkshire Region', 'London Region'],
#       dtype=object)

# %%
student_info['imd_band'].unique()
# Out:
# array(['90-100%', '20-30%', '30-40%', '50-60%', '80-90%', '70-80%', nan,
#        '60-70%', '40-50%', '10-20', '0-10%'], dtype=object)

# %%
(student_info['imd_band'].isna().sum() / student_info.shape[0])*100
# Out:
# np.float64(3.408707391157611)

# %%
student_info.shape
# Out:
# (32593, 12)

# %%
student_info[student_info['region'] == 'East Anglian Region']
# Out:
#       code_module code_presentation  id_student gender               region  \
# 0             AAA             2013J       11391      M  East Anglian Region
# 8             AAA             2013J       52130      F  East Anglian Region
# 11            AAA             2013J       58873      F  East Anglian Region
# 12            AAA             2013J       59185      M  East Anglian Region
# 15            AAA             2013J       65002      F  East Anglian Region
# ...           ...               ...         ...    ...                  ...
# 32539         GGG             2014J      697325      F  East Anglian Region
# 32557         GGG             2014J     1827650      F  East Anglian Region
# 32565         GGG             2014J     2004143      F  East Anglian Region
# 32582         GGG             2014J     2475886      F  East Anglian Region
# 32589         GGG             2014J     2645731      F  East Anglian Region
#
# ...

# %%
student_info.isna().sum()
# Out:
# code_module                0
# code_presentation          0
# id_student                 0
# gender                     0
# region                     0
# highest_education          0
# imd_band                1111
# age_band                   0
# num_of_prev_attempts       0
# studied_credits            0
# disability                 0
# final_result               0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
import numpy as np

# %%
imp_mode = SimpleImputer(missing_values=np.nan , strategy= 'most_frequent')

# %%
student_info_cleaned = imp_mode.fit_transform(student_info)

# %%
student_info_cleaned = pd.DataFrame(student_info_cleaned, columns= student_info.columns)

# %%
student_info_cleaned.sample(10)
# Out:
#       code_module code_presentation id_student gender                region  \
# 16178         DDD             2013J    2175266      M                 Wales
# 32108         GGG             2014J     644252      F   East Anglian Region
# 11898         CCC             2014J     620819      M               Ireland
# 2695          BBB             2013J     287309      F     South West Region
# 13898         DDD             2013B     544296      F         London Region
# 22517         FFF             2013B     334224      M  North Western Region
# 24803         FFF             2013J     569016      M  West Midlands Region
# 26620         FFF             2014B     550498      M      Yorkshire Region
# 4102          BBB             2013J     596583      F              Scotland
# 12451         CCC             2014J     675374      M          South Region
#
#            highest_education imd_band age_band num_of_prev_attempts  \
# ...

# %%
student_info_cleaned.isna().sum()
# Out:
# code_module             0
# code_presentation       0
# id_student              0
# gender                  0
# region                  0
# highest_education       0
# imd_band                0
# age_band                0
# num_of_prev_attempts    0
# studied_credits         0
# disability              0
# final_result            0
# dtype: int64

# %%
student_info_cleaned.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
from scipy.stats import chi2_contingency

# %%
table = pd.crosstab(student_info_cleaned['highest_education'],student_info_cleaned['final_result'])
chi2 , p,dof, expected = chi2_contingency(table)

# %%
table2 = pd.crosstab(student_info_cleaned['imd_band'])

# %%
print("p-value",p)
# Out:
# p-value 9.18211300726649e-212

# %%
dof
# Out:
# 12

# %%
expected
# Out:
# array([[1303.10434756, 3038.85312797, 5326.61138895, 4376.43113552],
#        [ 438.85251434, 1023.40870739, 1793.86770165, 1473.87107661],
#        [1220.80790354, 2846.93694965, 4990.21378824, 4100.04135857],
#        [  32.19488847,   75.07882061,  131.60086522,  108.1254257 ],
#        [  29.04034609,   67.72239438,  118.70625594,   97.53100359]])

# %%
table
# Out:
# final_result                 Distinction  Fail  Pass  Withdrawn
# highest_education
# A Level or Equivalent               1496  2707  5812       4030
# HE Qualification                     697   790  1960       1283
# Lower Than A Level                   727  3426  4385       4620
# No Formal quals                       16    95    87        149
# Post Graduate Qualification           88    34   117         74

# %%
student_info_cleaned['final_result'].value_counts(normalize= True)
# Out:
# final_result
# Pass           0.379253
# Withdrawn      0.311601
# Fail           0.216365
# Distinction    0.092781
# Name: proportion, dtype: float64
