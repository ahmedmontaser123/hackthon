# %%
import pandas as pd

# %%
Data = pd.read_csv("/home/ahmed122/Personal/Hackathon/hackthon/data/final_vle.csv")

# %%
Data.head()
# Out:
#    index code_module code_presentation  id_student gender  \
# 0      0         AAA             2013J       11391      M
# 1      1         AAA             2013J       28400      F
# 2      2         AAA             2013J       30268      F
# 3      3         AAA             2013J       31604      F
# 4      4         AAA             2013J       32885      F
#
#                  region      highest_education imd_band age_band  \
# 0   East Anglian Region       HE Qualification  90-100%     55<=
# 1              Scotland       HE Qualification   20-30%    35-55
# 2  North Western Region  A Level or Equivalent   30-40%    35-55
# 3     South East Region  A Level or Equivalent   50-60%    35-55
# 4  West Midlands Region     Lower Than A Level   50-60%     0-35
#
#    num_of_prev_attempts  studied_credits disability final_result  \
# 0                     0              240          N         Pass
# 1                     0               60          N         Pass
# ...

# %%
Data.shape
# Out:
# (32593, 20)

# %%
import numpy as np

# %%
def calc_na_percentage(Data:pd.DataFrame) -> list:
    values = []
    for column in Data.columns:
        na = Data[column].isna().sum()/Data.shape[0]*100
        values.append(column)
        values.append(na)
    return values

# %%
calc_na_percentage(Data)
# Out:
# ['index',
#  np.float64(0.0),
#  'code_module',
#  np.float64(0.0),
#  'code_presentation',
#  np.float64(0.0),
#  'id_student',
#  np.float64(0.0),
#  'gender',
#  np.float64(0.0),
#  'region',
#  np.float64(0.0),
#  'highest_education',
#  np.float64(0.0),
#  'imd_band',
#  np.float64(3.408707391157611),
#  'age_band',
#  np.float64(0.0),
#  'num_of_prev_attempts',
#  np.float64(0.0),
#  'studied_credits',
#  np.float64(0.0),
#  'disability',
#  np.float64(0.0),
#  'final_result',
#  np.float64(0.0),
#  'date_registration',
#  np.float64(0.13806645598748196),
#  'date_unregistration',
#  np.float64(69.09765900653515),
#  'avg_score',
#  np.float64(20.78053569784923),
#  'max_score',
#  np.float64(20.78053569784923),
#  'num_submissions',
#  np.float64(20.709968398122296),
#  'total_clicks',
#  np.float64(10.324302764397263),
#  'activity_diversity',
#  np.float64(10.324302764397263)]

# %%
Data['date_unregistration']= Data['date_unregistration'].fillna(0)

# %%
Data[(Data['avg_score'].isna()) & (Data['final_result']=='Pass')]
# Out:
# Empty DataFrame
# Columns: [index, code_module, code_presentation, id_student, gender, region, highest_education, imd_band, age_band, num_of_prev_attempts, studied_credits, disability, final_result, date_registration, date_unregistration, avg_score, max_score, num_submissions, total_clicks, activity_diversity]
# Index: []

# %%
Data = Data[~((Data['final_result'].isin(['Pass'])) & (Data['avg_score'].isna())) ]

# %%
Data[(Data['avg_score'].isna()) & (Data['final_result']=='Pass')]
# Out:
# Empty DataFrame
# Columns: [index, code_module, code_presentation, id_student, gender, region, highest_education, imd_band, age_band, num_of_prev_attempts, studied_credits, disability, final_result, date_registration, date_unregistration, avg_score, max_score, num_submissions, total_clicks, activity_diversity]
# Index: []

# %%
Data[(Data['final_result']=='Withdrawn')&(Data['date_unregistration']<=60)]
# Out:
#        index code_module code_presentation  id_student gender  \
# 2          2         AAA             2013J       30268      F
# 44        44         AAA             2013J      135335      F
# 54        54         AAA             2013J      147793      F
# 72        72         AAA             2013J      181316      F
# 79        79         AAA             2013J      188278      M
# ...      ...         ...               ...         ...    ...
# 32523  32523         GGG             2014J      695143      F
# 32541  32541         GGG             2014J      697364      F
# 32570  32570         GGG             2014J     2239862      M
# 32576  32576         GGG             2014J     2338614      F
# 32586  32586         GGG             2014J     2608143      M
#
#                      region      highest_education imd_band age_band  \
# 2      North Western Region  A Level or Equivalent   30-40%    35-55
# 44      East Anglian Region     Lower Than A Level   20-30%     0-35
# ...

# %%
Data_tested = pd.read_csv("/home/ahmed122/Personal/Hackathon/hackthon/data/studentInfo.csv")

# %%
Data_tested[Data_tested['id_student']==1777834]
# Out:
#       code_module code_presentation  id_student gender               region  \
# 12893         CCC             2014J     1777834      F  East Anglian Region
#
#            highest_education imd_band age_band  num_of_prev_attempts  \
# 12893  A Level or Equivalent   80-90%    35-55                     0
#
#        studied_credits disability final_result
# 12893               60          N         Pass
